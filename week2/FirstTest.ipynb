# %% [markdown]
# #想要把第一個 CSV 檔讀入

# %%
import pandas as pd

df = pd.read_csv('FirstTest.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14988\2960397884.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('109.csv')
#       4
#       5 df.head()
#
# D:\P\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# D:\P\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# D:\P\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# D:\P\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# D:\P\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# D:\P\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '109.csv'

# %%
temp = df[['Complex2Name', 'FValue']]
temp
# Out:
#    Complex2Name   FValue
# 0           NaN  4233275
# 1           NaN  2231696
# 2           NaN  7219409
# 3          經常支出  4216055
# 4          經常支出  2129704
# 5          經常支出  5917663
# 6          資本支出   193089
# 7          資本支出   101992
# 8          資本支出  2037579
# 9          償還借款        0
# 10         償還借款        0
# 11         償還借款   228382
# 12     經常支出報廢金額        0
# 13     經常支出報廢金額        0
# 14          NaN  4631696
# 15          NaN  2205193
# 16          NaN  7185789
# 17         經常支出  4362823
# 18         經常支出  2084315
# 19         經常支出  5934732
# 20         資本支出   209431
# 21         資本支出    60252
# 22         資本支出  2111732
# 23         償還借款        0
# 24         償還借款        0
# 25         償還借款   341616
# 26     經常支出報廢金額   152212
# 27     折舊、折耗及攤銷   465977
# 28     折舊、折耗及攤銷        0
# 29     折舊、折耗及攤銷        0
# 30     經常支出報廢金額        0
# 31     經常支出報廢金額        0
# 32     經常支出報廢金額   382575
# 33     折舊、折耗及攤銷   481232
# 34     折舊、折耗及攤銷        0
# 35     折舊、折耗及攤銷        0

# %%
Type = temp.groupby(['Complex2Name'])['FValue'].sum().reset_index()

# %%
Type['year'] = 2015
Type
# Out:
#   Complex2Name    FValue  year
# 0         償還借款    569998  2015
# 1     折舊、折耗及攤銷    947209  2015
# 2         經常支出  24645292  2015
# 3     經常支出報廢金額    534787  2015
# 4         資本支出   4714075  2015

# %% [markdown]
# #讀入 2016 ~ 2018 年的預算資料

# %%
df2016 = pd.read_csv('2016.csv')
df2017 = pd.read_csv('2017.csv')
df2018 = pd.read_csv('2018.csv')

# %%
new = df2016[['Complex2Name', 'FValue']].groupby(['Complex2Name'])['FValue'].sum().reset_index()

# %%
new['year'] = 2016

# %%
new
# Out:
#   Complex2Name    FValue  year
# 0         償還借款   1014559  2016
# 1     折舊、折耗及攤銷    975539  2016
# 2         經常支出  24209205  2016
# 3     經常支出報廢金額    357410  2016
# 4         資本支出   5365361  2016

# %%
frames = [Type, new]

result = pd.concat(frames)

# %%
result
# Out:
#   Complex2Name    FValue  year
# 0         償還借款    569998  2015
# 1     折舊、折耗及攤銷    947209  2015
# 2         經常支出  24645292  2015
# 3     經常支出報廢金額    534787  2015
# 4         資本支出   4714075  2015
# 0         償還借款   1014559  2016
# 1     折舊、折耗及攤銷    975539  2016
# 2         經常支出  24209205  2016
# 3     經常支出報廢金額    357410  2016
# 4         資本支出   5365361  2016
