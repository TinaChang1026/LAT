# %% [markdown]
# #把第一個CSV檔讀入

# %%
import pandas as pd

df = pd.read_csv('111_library1.csv')

print(df.to_string())
# Out:
#                    項目   公立大學及獨立學院   私立大學及獨立學院   公立專科學校     私立專科學校
# 0      中文圖書收藏冊數(冊)-總類   2,628,030   1,849,104    8,754     29,088
# 1     中文圖書收藏冊數(冊)-哲學類   1,051,868   1,644,401   14,654     89,275
# 2     中文圖書收藏冊數(冊)-宗教類     495,885     793,426    4,098     32,883
# 3     中文圖書收藏冊數(冊)-科學類   1,288,757   2,264,148   14,908     86,338
# 4   中文圖書收藏冊數(冊)-應用科學類   2,646,031   5,251,965   49,312    277,519
# 5   中文圖書收藏冊數(冊)-社會科學類   4,196,018   4,781,169   26,069    153,879
# 6     中文圖書收藏冊數(冊)-史地類   2,318,875   2,315,095   16,827     79,750
# 7   中文圖書收藏冊數(冊)-語言文學類   3,766,764   5,367,944   41,388    274,231
# 8     中文圖書收藏冊數(冊)-藝術類   1,379,064   1,967,475   12,822     62,709
# 9         外文圖書收藏冊數(冊)   8,571,090   7,212,203   10,447    145,457
# 10             電子書(種)  38,938,602  53,377,290   21,279    462,019
# 11         圖書閱覽座位數(個)      52,650      73,101      475      3,840
# 12         圖書借閱人次(人次)   1,134,885   1,224,818    3,456     45,206
# ...

# %%
df
# Out:
#                    項目   公立大學及獨立學院   私立大學及獨立學院   公立專科學校     私立專科學校
# 0      中文圖書收藏冊數(冊)-總類   2,628,030   1,849,104    8,754     29,088
# 1     中文圖書收藏冊數(冊)-哲學類   1,051,868   1,644,401   14,654     89,275
# 2     中文圖書收藏冊數(冊)-宗教類     495,885     793,426    4,098     32,883
# 3     中文圖書收藏冊數(冊)-科學類   1,288,757   2,264,148   14,908     86,338
# 4   中文圖書收藏冊數(冊)-應用科學類   2,646,031   5,251,965   49,312    277,519
# 5   中文圖書收藏冊數(冊)-社會科學類   4,196,018   4,781,169   26,069    153,879
# 6     中文圖書收藏冊數(冊)-史地類   2,318,875   2,315,095   16,827     79,750
# 7   中文圖書收藏冊數(冊)-語言文學類   3,766,764   5,367,944   41,388    274,231
# 8     中文圖書收藏冊數(冊)-藝術類   1,379,064   1,967,475   12,822     62,709
# 9         外文圖書收藏冊數(冊)   8,571,090   7,212,203   10,447    145,457
# 10             電子書(種)  38,938,602  53,377,290   21,279    462,019
# 11         圖書閱覽座位數(個)      52,650      73,101      475      3,840
# 12         圖書借閱人次(人次)   1,134,885   1,224,818    3,456     45,206
# ...
