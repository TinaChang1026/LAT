# %%
import pandas as pd

df = pd.read_csv('107.csv')

df.head()
# Out:
#            RptNo                 RptName StatCourseNo  \
# 0  10440-01-02-2  臺中市特殊教育學校教育經費概況(預、決算數)  1044001a017
# 1  10440-01-02-2  臺中市特殊教育學校教育經費概況(預、決算數)  1044001a017
# 2  10440-01-02-2  臺中市特殊教育學校教育經費概況(預、決算數)  1044001a017
# 3  10440-01-02-2  臺中市特殊教育學校教育經費概況(預、決算數)  1044001a018
# 4  10440-01-02-2  臺中市特殊教育學校教育經費概況(預、決算數)  1044001a018
#
#                         StatCourseName              DataDate      PlaceNo  \
# 0  特殊教育學校教育經費概況(預、決算數)-預算數-經費來源(單位:千元)  2018/1/1 上午 12:00:00  10000066000
# 1  特殊教育學校教育經費概況(預、決算數)-預算數-經費來源(單位:千元)  2018/1/1 上午 12:00:00  10000066000
# 2  特殊教育學校教育經費概況(預、決算數)-預算數-經費來源(單位:千元)  2018/1/1 上午 12:00:00  10000066000
# 3  特殊教育學校教育經費概況(預、決算數)-預算數-經費支出(單位:千元)  2018/1/1 上午 12:00:00  10000066000
# 4  特殊教育學校教育經費概況(預、決算數)-預算數-經費支出(單位:千元)  2018/1/1 上午 12:00:00  10000066000
#
#   PlaceName PeriodNo PeriodName      Complex1  ... Complex5  Complex5Name  \
# 0       臺中市        Y          年  230010000101  ...        0           NaN
# ...

# %%
temp = df[['Complex2Name', 'FValue']]
temp
# Out:
#    Complex2Name  FValue
# 0           NaN       0
# 1           NaN  421768
# 2           NaN   68615
# 3          經常支出       0
# 4          經常支出  409255
# 5          經常支出   63840
# 6          資本支出       0
# 7          資本支出   12513
# 8          資本支出    4775
# 9          償還借款       0
# 10         償還借款       0
# 11         償還借款       0
# 12     經常支出報廢金額       0
# 13     經常支出報廢金額       0
# 14     經常支出報廢金額    6330
# 15     折舊、折耗及攤銷       0
# 16     折舊、折耗及攤銷       0
# 17     折舊、折耗及攤銷       0
# 18          NaN       0
# 19          NaN  430356
# 20          NaN  120024
# 21         經常支出       0
# 22         經常支出  404147
# 23         經常支出   52439
# 24         資本支出       0
# 25         資本支出   11920
# 26         資本支出    3882
# 27         償還借款       0
# 28         償還借款       0
# 29         償還借款       0
# 30     經常支出報廢金額       0
# 31     經常支出報廢金額       0
# 32     經常支出報廢金額     499
# 33     折舊、折耗及攤銷       0
# 34     折舊、折耗及攤銷   27140
# 35     折舊、折耗及攤銷    6023

# %%
Type = temp.groupby(['Complex2Name'])['FValue'].sum().reset_index()
Type
# Out:
#   Complex2Name  FValue
# 0         償還借款       0
# 1     折舊、折耗及攤銷   33163
# 2         經常支出  929681
# 3     經常支出報廢金額    6829
# 4         資本支出   33090

# %% [markdown]
# 1.在107年的資料中，總共有哪些不同項目的支出？

# %%
Type['year'] = 107
Type
# Out:
#   Complex2Name  FValue  year
# 0         償還借款       0   107
# 1     折舊、折耗及攤銷   33163   107
# 2         經常支出  929681   107
# 3     經常支出報廢金額    6829   107
# 4         資本支出   33090   107

# %% [markdown]
# 2.107年的總支出是多少？

# %%
data_sum107 = Type.groupby(['year'])['FValue'].sum().reset_index()
data_sum107
# Out:
#    year   FValue
# 0   107  1002763

# %%
df104 = pd.read_csv('104.csv')
df105 = pd.read_csv('105.csv')
df106 = pd.read_csv('106.csv')

# %% [markdown]
# 3.在104年的資料中，總共有哪些不同項目的支出？

# %%
new104 = df104[['Complex2Name', 'FValue']].groupby(['Complex2Name'])['FValue'].sum().reset_index()
new104['year'] = 104
new104
# Out:
#   Complex2Name   FValue  year
# 0         償還借款        0   104
# 1     折舊、折耗及攤銷   137664   104
# 2         經常支出  1055292   104
# 3     經常支出報廢金額     2038   104
# 4         資本支出    58328   104

# %% [markdown]
# 4.104年的總支出是多少？

# %%
data_sum104 = new104.groupby(['year'])['FValue'].sum().reset_index()
data_sum104
# Out:
#    year   FValue
# 0   104  1253322

# %% [markdown]
# 5.在105年的資料中，總共有哪些不同項目的支出？

# %%
new105 = df105c
new105['year'] = 105
new105
# Out:
#   Complex2Name   FValue  year
# 0         償還借款        0   105
# 1     折舊、折耗及攤銷   129804   105
# 2         經常支出  1083520   105
# 3     經常支出報廢金額        0   105
# 4         資本支出    76403   105

# %% [markdown]
# 6.105年的總支出是多少？

# %%
data_sum105 = new105.groupby(['year'])['FValue'].sum().reset_index()
data_sum105
# Out:
#    year   FValue
# 0   105  1289727

# %% [markdown]
# 7.在106年的資料中，總共有哪些不同項目的支出？

# %%
new106 = df106[['Complex2Name', 'FValue']].groupby(['Complex2Name'])['FValue'].sum().reset_index()
new106['year'] = 106
new106
# Out:
#   Complex2Name  FValue  year
# 0         償還借款       0   106
# 1     折舊、折耗及攤銷       0   106
# 2         經常支出  922385   106
# 3     經常支出報廢金額    1536   106
# 4         資本支出   48153   106

# %% [markdown]
# 8.106年的總支出是多少？

# %%
data_sum106 = new106.groupby(['year'])['FValue'].sum().reset_index()
data_sum106
# Out:
#    year  FValue
# 0   106  972074

# %% [markdown]
# 9.107~104年各個項目的支出分別為多少？

# %%
frames = [Type, new106, new105, new104]

result = pd.concat(frames)

result
# Out:
#   Complex2Name   FValue  year
# 0         償還借款        0   107
# 1     折舊、折耗及攤銷    33163   107
# 2         經常支出   929681   107
# 3     經常支出報廢金額     6829   107
# 4         資本支出    33090   107
# 0         償還借款        0   106
# 1     折舊、折耗及攤銷        0   106
# 2         經常支出   922385   106
# 3     經常支出報廢金額     1536   106
# 4         資本支出    48153   106
# 0         償還借款        0   105
# 1     折舊、折耗及攤銷   129804   105
# 2         經常支出  1083520   105
# 3     經常支出報廢金額        0   105
# 4         資本支出    76403   105
# 0         償還借款        0   104
# 1     折舊、折耗及攤銷   137664   104
# 2         經常支出  1055292   104
# 3     經常支出報廢金額     2038   104
# 4         資本支出    58328   104

# %% [markdown]
# 10.不同項目四年來的總支出分別為多少？

# %%
new_all = result[['Complex2Name', 'FValue', 'year']].groupby(['Complex2Name'])['FValue'].sum().reset_index()
new_all
# Out:
#   Complex2Name   FValue
# 0         償還借款        0
# 1     折舊、折耗及攤銷   300631
# 2         經常支出  3990878
# 3     經常支出報廢金額    10403
# 4         資本支出   215974

# %% [markdown]
# 11.104~107年各年的總支出是多少？

# %%
data_sum = result.groupby(['year'])['FValue'].sum().reset_index()
data_sum
# Out:
#    year   FValue
# 0   104  1253322
# 1   105  1289727
# 2   106   972074
# 3   107  1002763

# %% [markdown]
# 12.104~107年的總支出是多少？

# %%
data=new_all['FValue'].sum(axis=0)
data
# Out:
# 4517886
