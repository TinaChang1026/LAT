# %% [markdown]
# #把第一個CSV檔讀入

# %%
import pandas as pd

df = pd.read_csv('1.csv')

print(df.to_string())
# Out:
#              年度   低收入戶戶數   低收入戶人數   低收入戶男性人數   低收入戶女性人數   中低收入戶戶數   中低收入戶人數   中低收入戶男性人數   中低收入戶女性人數
# 0          2,003   76,406  187,875     92,793     95,082       NaN       NaN         NaN         NaN
# 1          2,004   82,783  204,216    101,366    102,850       NaN       NaN         NaN         NaN
# 2          2,005   84,823  211,292    104,745    106,547       NaN       NaN         NaN         NaN
# 3          2,006   89,900  218,166    108,097    110,069       NaN       NaN         NaN         NaN
# 4          2,007   90,682  220,990    110,639    110,351       NaN       NaN         NaN         NaN
# 5          2,008   93,032  223,697    113,281    110,416       NaN       NaN         NaN         NaN
# 6          2,009  105,265  256,342    130,515    125,827       NaN       NaN         NaN         NaN
# 7          2,010  112,200  273,361    140,672    132,689       NaN       NaN         NaN         NaN
# ...

# %%
df
# Out:
#              年度   低收入戶戶數   低收入戶人數   低收入戶男性人數   低收入戶女性人數   中低收入戶戶數   中低收入戶人數   \
# 0          2,003   76,406  187,875     92,793     95,082       NaN       NaN
# 1          2,004   82,783  204,216    101,366    102,850       NaN       NaN
# 2          2,005   84,823  211,292    104,745    106,547       NaN       NaN
# 3          2,006   89,900  218,166    108,097    110,069       NaN       NaN
# 4          2,007   90,682  220,990    110,639    110,351       NaN       NaN
# 5          2,008   93,032  223,697    113,281    110,416       NaN       NaN
# 6          2,009  105,265  256,342    130,515    125,827       NaN       NaN
# 7          2,010  112,200  273,361    140,672    132,689       NaN       NaN
# 8          2,011  128,237  314,282    160,644    153,638    35,420   120,042
# 9          2,012  145,613  357,446    182,335    175,111    88,988   282,019
# 10         2,013  148,590  361,765    186,087    175,678   108,589   334,391
# ...
